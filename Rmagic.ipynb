# %% [markdown]
# # RPY2 mode: transferring variables back and forth from python

# %%
import Rmagic; reload(Rmagic)import numpy as npfrom Rmagic import rmagicrmagic.shell = {'X': np.random.standard_normal(40),                'Y': np.random.standard_normal(40)}

# %% [markdown]
# ## Line magic

# %%
The line magic allows passing variables from python to rpy2 in one line calls.

# %% [markdown]
# ## Cell level magic

# %% [markdown]
# The cell magic executes a cell of R code, capturing the stdout of R as well as any plots made. The args to the magic allowpassing python objects back and forth from python to rpy2 with --inputs denoting variables to be assigned in R and--outputs to be variables retrieved from rpy2 after executing the code.

# %% [markdown]
# In this example, data that is generated in python will be passed to R, a linear model will be fit and the variable 'r' (which happens to be the residuals from the linear model) will be passed back to ipython.

# %%
snippet = '''a=lm(Y~X)# since I called print, I will see the summary of the modelprint(summary(a))# this will produce one plotplot(X, Y, pch=23, bg='orange', cex=2)# by default R creates 4 plots for plotting an lm, so there will be five plots in totalplot(a)# this next print statement will show me summary(X)print(summary(X))r = resid(a)'''

# %%
opts = '--inputs=X,Y --outputs=r --bg="gray" --width=700'

# %%
rmagic.cell_magic(opts, snippet)
# Out:
# Call:lm(formula = Y ~ X)Residuals:     Min       1Q   Median       3Q      Max -1.87875 -0.45893  0.06137  0.52693  1.98218 Coefficients:            Estimate Std. Error t value Pr(>|t|)(Intercept)  0.07860    0.14932   0.526    0.602X           -0.04961    0.16245  -0.305    0.762Residual standard error: 0.9357 on 38 degrees of freedomMultiple R-squared: 0.002448,	Adjusted R-squared: -0.0238 F-statistic: 0.09327 on 1 and 38 DF,  p-value: 0.7617     Min.  1st Qu.   Median     Mean  3rd Qu.     Max. -2.14300 -0.79640 -0.05716 -0.12470  0.54230  1.68400

# %% [markdown]
# As we can see, the ipython shell now has a variable 'r'.

# %%
rmagic.shell['r']
# Out:
# array([-1.39513803,  1.33772184,  1.83179854,  0.36610305,  0.96081487,       -0.14496471, -1.66904678,  0.08094194, -0.92677897,  0.08765797,       -0.44471574,  1.12595861, -0.07260403, -0.6469713 ,  1.98218166,        0.16126364, -0.398235  ,  0.33220492, -0.50156541,  0.49511847,        1.439103  ,  0.13969161,  0.08650864,  0.04180297, -1.01167516,        0.00254071,  0.10652741, -0.39608308, -1.87875051,  0.77741284,       -0.27112997,  0.6223719 , -0.71976088, -0.39632793, -1.3061937 ,        0.23652611, -0.32951786, -1.58305365,  1.19153525,  0.68672675])

# %% [markdown]
# For now, all outputs are cast to be np.arrays (good or bad)

# %%
opts_a = '--inputs=X,Y --outputs=a --bg="gray" --width=700'rmagic.cell_magic(opts_a, snippet)
# Out:
# Call:lm(formula = Y ~ X)Residuals:     Min       1Q   Median       3Q      Max -1.87875 -0.45893  0.06137  0.52693  1.98218 Coefficients:            Estimate Std. Error t value Pr(>|t|)(Intercept)  0.07860    0.14932   0.526    0.602X           -0.04961    0.16245  -0.305    0.762Residual standard error: 0.9357 on 38 degrees of freedomMultiple R-squared: 0.002448,	Adjusted R-squared: -0.0238 F-statistic: 0.09327 on 1 and 38 DF,  p-value: 0.7617     Min.  1st Qu.   Median     Mean  3rd Qu.     Max. -2.14300 -0.79640 -0.05716 -0.12470  0.54230  1.68400

# %%
rmagic.shell['a']
# Out:
# array([(Intercept)           X  0.07860157 -0.04961173 ,                 1           2           3           4           5           6 -1.39513803  1.33772184  1.83179854  0.36610305  0.96081487 -0.14496471           7           8           9          10          11          12 -1.66904678  0.08094194 -0.92677897  0.08765797 -0.44471574  1.12595861          13          14          15          16          17          18 -0.07260403 -0.64697130  1.98218166  0.16126364 -0.39823500  0.33220492          19          20          21          22          23          24 -0.50156541  0.49511847  1.43910300  0.13969161  0.08650864  0.04180297          25          26          27          28          29          30 -1.01167516  0.00254071  0.10652741 -0.39608308 -1.87875051  0.77741284          31          32          33          34          35          36 -0.27112997  0.62237190 -0.71976088 -0.39632793 -1.30619370  0.23652611          37          38          39          40 -0.32951786 -1.58305365  1.19153525  0.68672675 ,        (Intercept)            X                                                     -0.536251125  0.285753815  1.973523676  0.695225528  0.743169807  0.291307510                                                                               -1.899914856  0.024758052 -0.701429911  0.201756630 -0.323388449  1.143976526                                                                                0.137304050 -0.003395083  2.406137485  0.458794233 -0.356009704  0.721953888                                                                               -0.145244709  0.406797589  1.915079329  0.633623396  0.254988948  0.073696159                                                                               -0.868159819  0.120491576  0.432596936 -0.074618948 -1.667805333  0.709952624                                                                               -0.460074419  0.981751109 -0.241131315 -0.342444756 -0.987688936  0.636572672                                                     -0.164054317 -1.592566413  1.287275040  0.710873887 ,       [1] 2,                  1            2            3            4            5            6  0.097610001  0.040562520  0.075957100  0.116636053 -0.002052564  0.139895400            7            8            9           10           11           12 -0.004922928  0.032996341  0.094109619  0.069960130  0.071529274  0.049103569           13           14           15           16           17           18  0.090757794  0.184895555  0.137221838  0.109778301  0.054358345  0.129796445           19           20           21           22           23           24  0.122540062  0.026020258  0.148514099  0.152411749  0.081764933  0.052115519           25           26           27           28           29           30  0.076345705  0.070796341  0.115973340  0.114973633  0.090982922  0.030548552           31           32           33           34           35           36  0.004177571  0.123203981  0.149090046  0.056888957  0.114331232  0.132031777           37           38           39           40  0.081110073  0.043127394  0.065974910  0.050434060 ,       [1] 0 1,       $qr   (Intercept)           X1   -6.3245553  0.788747562    0.1581139 -5.759803983    0.1581139  0.037032214    0.1581139 -0.105324435    0.1581139  0.310028276    0.1581139 -0.186720887    0.1581139  0.320073158    0.1581139  0.187374079    0.1581139 -0.0264928110   0.1581139  0.0580187011   0.1581139  0.0525274612   0.1581139  0.1310065713   0.1581139 -0.0147630514   0.1581139 -0.3441996415   0.1581139 -0.1773647116   0.1581139 -0.0813256217   0.1581139  0.1126174018   0.1581139 -0.1513794319   0.1581139 -0.1259856020   0.1581139  0.2117869821   0.1581139 -0.2168821622   0.1581139 -0.2305220423   0.1581139  0.0167076124   0.1581139  0.1204662025   0.1581139  0.0356722826   0.1581139  0.0550923727   0.1581139 -0.1030052528   0.1581139 -0.0995067629   0.1581139 -0.0155508930   0.1581139  0.1959401431   0.1581139  0.2882258132   0.158 ...

# %% [markdown]
# # R shell

# %% [markdown]
# Sometimes, for teaching, it might be nice to really mimic an R session. The rshell cell magic does this in the notebook.We will repeat essentially the same example above but now $X$ and $Y$ are generated in R as we are not ableto pass data back and forth. It could be possible to pass arrays as strings, if we __really__ want to, but this seems wasteful.Note that this R process is completely unrelated to the one in rpy2 mode: it is a separate process run through ipython's InteractiveRunner.

# %%
from Rmagic import rshell# in shell mode, the process is a completely separate R process so no variables# are passed between R and python hence there are no --inputs --outputs argsopts_shell = ' --bg="yellow" --width=400'snippet_shell = '''Y = rnorm(40)X = rnorm(40) + 2 * Ya=lm(Y~X)# since I called print, I will see the summary of the modelprint(summary(a))# this will produce one plotplot(X, Y, pch=23, bg='orange', cex=2)# by default R creates 4 plots for plotting an lm, so there will be five plots in totalplot(a)# this next print statement will show me summary(X)print(summary(X))r = resid(a)'''

# %%
rshell.cell_magic(opts_shell, snippet_shell)
# Out:
# > Y = rnorm(40)> X = rnorm(40) + 2 * Y> a=lm(Y~X)> print(summary(a))Call:lm(formula = Y ~ X)Residuals:     Min       1Q   Median       3Q      Max -1.09901 -0.27308 -0.04917  0.29769  1.13014 Coefficients:            Estimate Std. Error t value Pr(>|t|)    (Intercept)  0.05484    0.07225   0.759    0.453    X            0.42097    0.02799  15.040   <2e-16 ***---Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1 Residual standard error: 0.449 on 38 degrees of freedomMultiple R-squared: 0.8562,	Adjusted R-squared: 0.8524 F-statistic: 226.2 on 1 and 38 DF,  p-value: < 2.2e-16 > plot(X, Y, pch=23, bg='orange', cex=2)> plot(a)> print(summary(X))   Min. 1st Qu.  Median    Mean 3rd Qu.    Max. -4.8850 -0.8557  0.7155  0.4811  1.5720  5.9090 > r = resid(a)>
